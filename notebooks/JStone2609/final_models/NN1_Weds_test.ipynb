# %%
from Preprocessing.data_clean import get_data, dropping_no_betting_data
from sklearn.preprocessing import MinMaxScaler
from sklearn import set_config
from sklearn.impute import SimpleImputer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Dropout
from keras.utils import get_custom_objects
import pandas as pd
import numpy as np
import pickle
import warnings

warnings.filterwarnings('ignore')

# %%
#Get the data from the bucket
data = get_data("../../../raw_data/hr_weds_only_rem.csv") ### CHANGE THIS PATH to get data from the bucket
print("data loaded")
# Out:
# data acquired with shape (298, 116)
# data loaded

# %%
"""1)  Getting the data and first round of preprocessing"""
    ###receiving all columns of data for user selected rows (by track and time)

    # #Get the data from the bucket
    # data = get_data("raw_data/hr_data_0409_221rem.csv") ### CHANGE THIS PATH to get data from the bucket
    # print("data loaded")

    #Fill in the missing odds
    # data = dropping_no_betting_data(data)
    # data = data.dropna(subset=['f_bsp', 'f_pm_15m', 'f_pm_10m', 'f_pm_05m' , 'f_pm_03m', 'f_pm_02m', 'f_pm_01m'], how='all')
    # def impute_row(row):
    #     row = row.fillna(method='ffill').fillna(method='bfill')
    #     return row
    # columns_to_impute = ['f_bsp', 'f_pm_15m', 'f_pm_10m', 'f_pm_05m', 'f_pm_03m', 'f_pm_02m', 'f_pm_01m']
    # data[columns_to_impute] = data[columns_to_impute].apply(impute_row, axis=1)
    #Drop stall_position NAs
data = data[data['stall_position'].notna()]
    #Remove horses with odds over 50 at 5m before the race
    # data = data[(data['f_pm_05m'] <= 50)]
    #Reset index
data = data.reset_index(drop=True)

    #######################################################

# %%
"""2)  Filling the null L16 columns with 0s"""

X_preproc = data[[
        'iv_trainer_l16r', 'iv_jockey_l16r',
        'ae_trainer_l16r' ,'ae_jockey_l16r']]
X_preproc = X_preproc.fillna(0)

#######################################################

"""3)  Scaling the numerical values and defining X"""

#Adding f_runners and stall_position to X_preproc pre-scaling
X_preproc['f_runners'] = data['f_runners']
X_preproc['stall_position'] = data['stall_position']

# %%
#Loading scaler values and scaling 5 features
set_config(transform_output = "pandas")
with open('../../../api/scaler_updated2.pkl', 'rb') as f: # CHANGE THIS PATH to get the saved scalar
  loaded_scaler = pickle.load(f)
X = loaded_scaler.transform(X_preproc)

#Adding final 2 features that don't need scaling
X['pred_isp_prob'] = 1 / data['pred_isp']

#Matching the column order to the order of the original saved weights
X = X[['stall_position', 'iv_trainer_l16r', 'iv_jockey_l16r', 'ae_trainer_l16r', 'ae_jockey_l16r', 'pred_isp_prob', 'f_runners']]

# %%
#######################################################

#"""4)  Defining y"""

# NOT NEEDED IN CURRENT DESIGN (but keeping incase it becomes useful)

# def winner(x):
#         if x == 1:
#             return 1
#         else:
#             return 0
# data['f_place'] = data['f_place'].apply(winner)
# y = data[['f_place', 'pred_isp']]

# y = data[['f_place', 'pred_isp']]

#######################################################

"""5) Defining backtest and changing commision to 2%"""

# Define a function to create a new profit column with 2% commision
# def fill_01m_profit(data):
#     def fill_nan(row):
#         if row['f_place'] == 0:
#             return -1
#         elif row['f_place'] == 1:
#             return (row['f_pm_01m'] - 1) * 0.98
#         else:
#             return row['f_pm_01m_p_back']

# # Apply the lambda function to create 01m_profit column
#     data['01m_profit'] = data.apply(fill_nan, axis=1)
#     return data

# data = fill_01m_profit(data)

backtest = data[['f_ko', 'f_track', 'f_id', 'id','f_horse']]

#######################################################

# %%
"""6)  Model Architecture"""

NN = Sequential()
NN.add(InputLayer(input_shape=(7, ))) # input layer
NN.add(Dense(32, activation='relu')) # hidden layer 1
NN.add(Dense(2, activation='softmax')) # output layer

#######################################################

"""7)  Loading Weights"""


NN.load_weights("../../../api/custom_scorer0.05_7input_l16_05mfilter_01mplace") ##CHANGE PATH TO LOAD MODEL WEIGHTS


#######################################################

# %%
"""8)  Creating preds"""

y_pred = NN.predict(X)

#######################################################

"""9) Creating backtest table"""

backtest['model_preds'] = y_pred[:, 0:1]
backtest['model_preds'] = round(backtest['model_preds'],2)
backtest = backtest.sort_values(['model_preds'], ascending = False)
backtest_live = backtest.drop(columns=['f_id', 'id'])
def bet_or_nobet(model_preds):
    if model_preds > 0.9:
        return "BET"
    else:
        return "NO BET"

backtest_live['bet'] = backtest_live.apply(lambda row: bet_or_nobet(row['model_preds']), axis=1)
# Out:
# 10/10 [==============================] - 0s 350us/step

# %%
backtest_live
# Out:
#                  f_ko      f_track             f_horse  model_preds     bet
# 135  06/09/2023 16:40  GOWRAN PARK           Hale Bopp         1.00     BET
# 177  06/09/2023 17:15  GOWRAN PARK               Zahee         1.00     BET
# 247  06/09/2023 19:40         CORK          Tall Story         1.00     BET
# 270  06/09/2023 19:40         CORK            Andrassy         1.00     BET
# 269  06/09/2023 19:40         CORK             Lisieux         1.00     BET
# 24   06/09/2023 13:30    SOUTHWELL       Northern Rose         1.00     BET
# 134  06/09/2023 16:40  GOWRAN PARK               Nyota         1.00     BET
# 132  06/09/2023 16:40  GOWRAN PARK         Nancy Angel         1.00     BET
# 263  06/09/2023 19:40         CORK            Badinage         1.00     BET
# 256  06/09/2023 19:40         CORK       Famous Enough         1.00     BET
# 31   06/09/2023 13:55    LINGFIELD      Hold The Press         0.99     BET
# 46   06/09/2023 14:05    SOUTHWELL           Rise Hall         0.99     BET
# 252  06/09/2023 19:40         CORK     Saoirses Lulaby         0.99     BET
# 20   06/09/2023 13:30    SOUTHWELL          Lady Saxon         0.99     BET
# 153  06/09/2023 16:50    LINGFIELD        Grey Rosetta         0.99     BET
# 261  06/09/2023 19:40         CORK      Golden Warrior         0.99     BET
# 10   06/09/2023 13:10         BATH  Fishermans Cottage         0.99     BET
# 288  06/09/2023 21:00      KEMPTON        Stella Hogan         0.99     BET
# 151  06/09/2023 16:50    LINGFIELD    Arlecchinos Star         0.98     BET
# 141  06/09/2023 16:40  GOWRAN PARK         Rock Basher         0.98     BET
# 29   06/09/2023 13:55    LINGFIELD      Dream Frontier         0.98     BET
# 88   06/09/2023 15:40    LINGFIELD          Arabescato         0.97     BET
# 126  06/09/2023 16:34         BATH           Finn Star         0.96     BET
# 253  06/09/2023 19:40         CORK             Tijuana         0.96     BET
# 267  06/09/2023 19:40         CORK       Maid To Shine         0.96     BET
# 72   06/09/2023 15:25         BATH            Genuflex         0.96     BET
# 14   06/09/2023 13:30    SOUTHWELL           Raincloud         0.95     BET
# 262  06/09/2023 19:40         CORK           Flag High         0.95     BET
# 22   06/09/2023 13:30    SOUTHWELL       Lady Of Nepal         0.95     BET
# 161  06/09/2023 17:00    SOUTHWELL    Trinidad Calypso         0.94     BET
# 223  06/09/2023 18:10         CORK       Mount Ruapehu         0.94     BET
# 149  06/09/2023 16:50    LINGFIELD          King Elvis         0.94     BET
# 232  06/09/2023 19:30      KEMPTON            Fast Flo         0.94     BET
# 227  06/09/2023 18:10         CORK      Cash Or Crypto         0.93     BET
# 137  06/09/2023 16:40  GOWRAN PARK     Hurricane Helen         0.93     BET
# 48   06/09/2023 14:05    SOUTHWELL   Dancinginthewoods         0.93     BET
# 197  06/09/2023 17:25    LINGFIELD        Rainbow Sign         0.93     BET
# 111  06/09/2023 16:25    SOUTHWELL         My Sand Boy         0.92     BET
# 51   06/09/2023 14:05    SOUTHWELL     Mykonos St John         0.92     BET
# 189  06/09/2023 17:15  GOWRAN PARK        Cursory Exam         0.92     BET
# 145  06/09/2023 16:40  GOWRAN PARK        Doctor Grace         0.91     BET
# 33   06/09/2023 13:55    LINGFIELD       Dont Fight It         0.91     BET
# 264  06/09/2023 19:40         CORK        Jered Maddox         0.90  NO BET
# 207  06/09/2023 17:30    SOUTHWELL            Puffable         0.90  NO BET
# 249  06/09/2023 19:40         CORK        Will Be King         0.89  NO BET
# 186  06/09/2023 17:15  GOWRAN PARK      Admiral Nelson         0.88  NO BET
# 56   06/09/2023 14:15         BATH           Reversion         0.88  NO BET
# 246  06/09/2023 19:40         CORK          Cuala Bula         0.82  NO BET
# 107  06/09/2023 16:25    SOUTHWELL        Crystal Dawn         0.82  NO BET
# 12   06/09/2023 13:30    SOUTHWELL            Dalatara         0.81  NO BET
# 136  06/09/2023 16:40  GOWRAN PARK            Samhradh         0.81  NO BET
# 21   06/09/2023 13:30    SOUTHWELL        Anna Aurelia         0.79  NO BET
# 228  06/09/2023 18:10         CORK    Mickey The Steel         0.79  NO BET
# 254  06/09/2023 19:40         CORK     Catherine Chroi         0.78  NO BET
# 128  06/09/2023 16:40  GOWRAN PARK           Lisabetta         0.77  NO BET
# 66   06/09/2023 14:50         BATH      Glamorous Star         0.77  NO BET
# 237  06/09/2023 19:30      KEMPTON           Sams Hope         0.77  NO BET
# 131  06/09/2023 16:40  GOWRAN PARK        Bucky Larson         0.77  NO BET
# 43   06/09/2023 14:05    SOUTHWELL       Hotspur Harry         0.75  NO BET
# 168  06/09/2023 17:09         BATH      Pyrrhic Dancer         0.73  NO BET
# 139  06/09/2023 16:40  GOWRAN PARK            Coviglia         0.73  NO BET
# 183  06/09/2023 17:15  GOWRAN PARK     Sir John Monash         0.69  NO BET
# 200  06/09/2023 17:25    LINGFIELD     Florence Street         0.68  NO BET
# 221  06/09/2023 18:10         CORK       Pinar Del Rio         0.67  NO BET
# 152  06/09/2023 16:50    LINGFIELD             Gintini         0.65  NO BET
# 47   06/09/2023 14:05    SOUTHWELL  Light Up Our Stars         0.65  NO BET
# 268  06/09/2023 19:40         CORK       Miss Slovakia         0.63  NO BET
# 144  06/09/2023 16:40  GOWRAN PARK              Qaabil         0.60  NO BET
# 147  06/09/2023 16:50    LINGFIELD        Cabaret Show         0.47  NO BET
# 258  06/09/2023 19:40         CORK        Cherry Bloom         0.46  NO BET
# 274  06/09/2023 20:00      KEMPTON          Sea Urchin         0.46  NO BET
# 265  06/09/2023 19:40         CORK      Brookie Cookie         0.45  NO BET
# 229  06/09/2023 18:10         CORK    Ice Cold In Alex         0.44  NO BET
# 100  06/09/2023 16:00         BATH        Ae Fond Kiss         0.44  NO BET
# 93   06/09/2023 15:40    LINGFIELD     Phoenix Aquilus         0.43  NO BET
# 297  06/09/2023 21:00      KEMPTON          Enola Grey         0.38  NO BET
# 266  06/09/2023 19:40         CORK       Rose Of Malta         0.37  NO BET
# 240  06/09/2023 19:30      KEMPTON             Tamaluk         0.36  NO BET
# 187  06/09/2023 17:15  GOWRAN PARK         Bright Dick         0.33  NO BET
# 142  06/09/2023 16:40  GOWRAN PARK          Pink Socks         0.33  NO BET
# 257  06/09/2023 19:40         CORK            Sondheim         0.32  NO BET
# 85   06/09/2023 15:30  GOWRAN PARK              Nituna         0.30  NO BET
# 185  06/09/2023 17:15  GOWRAN PARK           Toriangel         0.25  NO BET
# 35   06/09/2023 13:55    LINGFIELD      Carry On Aitch         0.22  NO BET
# 119  06/09/2023 16:34         BATH        Two Plus Two         0.21  NO BET
# 101  06/09/2023 16:00         BATH          Reel Rosie         0.20  NO BET
# 239  06/09/2023 19:30      KEMPTON       Wadacre Grace         0.20  NO BET
# 214  06/09/2023 17:30    SOUTHWELL  Sir Rodneyredblood         0.20  NO BET
# 26   06/09/2023 13:55    LINGFIELD          Uno Grande         0.19  NO BET
# 212  06/09/2023 17:30    SOUTHWELL          Higher Law         0.19  NO BET
# 59   06/09/2023 14:15         BATH          Wiley Post         0.17  NO BET
# 271  06/09/2023 19:40         CORK              Amemri         0.17  NO BET
# 176  06/09/2023 17:15  GOWRAN PARK           Portmagee         0.15  NO BET
# 273  06/09/2023 20:00      KEMPTON     Charlies Choice         0.15  NO BET
# 28   06/09/2023 13:55    LINGFIELD   Romantic Memories         0.15  NO BET
# 110  06/09/2023 16:25    SOUTHWELL       Gypsy Whisper         0.15  NO BET
# 117  06/09/2023 16:25    SOUTHWELL           Meng Tian         0.14  NO BET
# 204  06/09/2023 17:30    SOUTHWELL           Cubanista         0.14  NO BET
# 172  06/09/2023 17:09         BATH             Irezumi         0.13  NO BET
# 222  06/09/2023 18:10         CORK            Iva Batt         0.12  NO BET
# 5    06/09/2023 13:10         BATH        Ruby Cottage         0.11  NO BET
# 190  06/09/2023 17:15  GOWRAN PARK      Relevant Range         0.11  NO BET
# 34   06/09/2023 13:55    LINGFIELD        Q Twenty Boy         0.10  NO BET
# 170  06/09/2023 17:09         BATH          Many Words         0.10  NO BET
# 116  06/09/2023 16:25    SOUTHWELL      Variety Island         0.07  NO BET
# 70   06/09/2023 14:50         BATH      Ange De LAmour         0.07  NO BET
# 292  06/09/2023 21:00      KEMPTON      Unlimited Data         0.06  NO BET
# 103  06/09/2023 16:00         BATH              Dovena         0.06  NO BET
# 230  06/09/2023 19:30      KEMPTON      Fitz Perfectly         0.06  NO BET
# 32   06/09/2023 13:55    LINGFIELD           Zous Baby         0.05  NO BET
# 38   06/09/2023 13:55    LINGFIELD        He Can Dance         0.04  NO BET
# 113  06/09/2023 16:25    SOUTHWELL          Muddy Lynn         0.04  NO BET
# 4    06/09/2023 13:10         BATH             Flagman         0.04  NO BET
# 238  06/09/2023 19:30      KEMPTON           Rose Bolt         0.04  NO BET
# 178  06/09/2023 17:15  GOWRAN PARK        Is That Love         0.04  NO BET
# 184  06/09/2023 17:15  GOWRAN PARK             Cnodian         0.03  NO BET
# 68   06/09/2023 14:50         BATH      Corinthian Kid         0.03  NO BET
# 164  06/09/2023 17:00    SOUTHWELL          London Eye         0.03  NO BET
# 243  06/09/2023 19:40         CORK           Goldmoyne         0.03  NO BET
# 129  06/09/2023 16:40  GOWRAN PARK            Pascalia         0.03  NO BET
# 9    06/09/2023 13:10         BATH    More Than Likely         0.03  NO BET
# 296  06/09/2023 21:00      KEMPTON         From Beyond         0.02  NO BET
# 133  06/09/2023 16:40  GOWRAN PARK            Plankton         0.02  NO BET
# 244  06/09/2023 19:40         CORK           Ferrybank         0.02  NO BET
# 49   06/09/2023 14:05    SOUTHWELL           Touchwood         0.02  NO BET
# 215  06/09/2023 17:30    SOUTHWELL           Jill Rose         0.02  NO BET
# 53   06/09/2023 14:15         BATH     Cabeza De Llave         0.02  NO BET
# 109  06/09/2023 16:25    SOUTHWELL         Kodebreaker         0.02  NO BET
# 58   06/09/2023 14:15         BATH        Connies Rose         0.01  NO BET
# 140  06/09/2023 16:40  GOWRAN PARK             Monzoon         0.01  NO BET
# 180  06/09/2023 17:15  GOWRAN PARK     Court Of Appeal         0.01  NO BET
# 55   06/09/2023 14:15         BATH   Glamorous Express         0.01  NO BET
# 210  06/09/2023 17:30    SOUTHWELL          Lady Nagin         0.01  NO BET
# 284  06/09/2023 20:30      KEMPTON        Sayifyouwill         0.01  NO BET
# 259  06/09/2023 19:40         CORK  Hope And Innocence         0.01  NO BET
# 76   06/09/2023 15:25         BATH     Highland Frolic         0.01  NO BET
# 123  06/09/2023 16:34         BATH        Susanbequick         0.01  NO BET
# 87   06/09/2023 15:40    LINGFIELD           Renardeau         0.01  NO BET
# 62   06/09/2023 14:15         BATH           Pepsi Cat         0.00  NO BET
# 248  06/09/2023 19:40         CORK            Han Solo         0.00  NO BET
# 241  06/09/2023 19:30      KEMPTON    Lordsbridge Girl         0.00  NO BET
# 242  06/09/2023 19:30      KEMPTON             Zaakara         0.00  NO BET
# 92   06/09/2023 15:40    LINGFIELD        Art De Vivre         0.00  NO BET
# 91   06/09/2023 15:40    LINGFIELD            Solution         0.00  NO BET
# 245  06/09/2023 19:40         CORK      Angels Feather         0.00  NO BET
# 27   06/09/2023 13:55    LINGFIELD            Boarhunt         0.00  NO BET
# 90   06/09/2023 15:40    LINGFIELD         Mukha Magic         0.00  NO BET
# 25   06/09/2023 13:55    LINGFIELD     No Turning Back         0.00  NO BET
# 94   06/09/2023 15:40    LINGFIELD          Bodygroove         0.00  NO BET
# 250  06/09/2023 19:40         CORK         Gurkha Girl         0.00  NO BET
# 251  06/09/2023 19:40         CORK         Von Krolock         0.00  NO BET
# 23   06/09/2023 13:30    SOUTHWELL     Midsummer Dance         0.00  NO BET
# 19   06/09/2023 13:30    SOUTHWELL             Rampant         0.00  NO BET
# 18   06/09/2023 13:30    SOUTHWELL      Angel Of Peace         0.00  NO BET
# 255  06/09/2023 19:40         CORK              Trueba         0.00  NO BET
# 74   06/09/2023 15:25         BATH            Spritzin         0.00  NO BET
# 95   06/09/2023 16:00         BATH          Avon Light         0.00  NO BET
# 89   06/09/2023 15:40    LINGFIELD     Arcadian Friend         0.00  NO BET
# 96   06/09/2023 16:00         BATH             Tamilla         0.00  NO BET
# 220  06/09/2023 18:10         CORK       Furnace Creek         0.00  NO BET
# 37   06/09/2023 13:55    LINGFIELD      Doves Of Peace         0.00  NO BET
# 102  06/09/2023 16:00         BATH         Warren Hill         0.00  NO BET
# 36   06/09/2023 13:55    LINGFIELD       Bear To Dream         0.00  NO BET
# 224  06/09/2023 18:10         CORK        Wave Machine         0.00  NO BET
# 225  06/09/2023 18:10         CORK             Ostraka         0.00  NO BET
# 226  06/09/2023 18:10         CORK    Collective Power         0.00  NO BET
# 73   06/09/2023 15:25         BATH       Dreams Adozen         0.00  NO BET
# 99   06/09/2023 16:00         BATH        Mayfair Gold         0.00  NO BET
# 98   06/09/2023 16:00         BATH        Flash Bardot         0.00  NO BET
# 97   06/09/2023 16:00         BATH        Divina Grace         0.00  NO BET
# 231  06/09/2023 19:30      KEMPTON       Lady Wormsley         0.00  NO BET
# 30   06/09/2023 13:55    LINGFIELD          Sir Sedric         0.00  NO BET
# 233  06/09/2023 19:30      KEMPTON     Sea Of Elegance         0.00  NO BET
# 234  06/09/2023 19:30      KEMPTON              Vinaka         0.00  NO BET
# 235  06/09/2023 19:30      KEMPTON       Evening Story         0.00  NO BET
# 236  06/09/2023 19:30      KEMPTON  Sail On Silverbird         0.00  NO BET
# 17   06/09/2023 13:30    SOUTHWELL             Fougere         0.00  NO BET
# 75   06/09/2023 15:25         BATH          Logistical         0.00  NO BET
# 16   06/09/2023 13:30    SOUTHWELL     Bletchley Storm         0.00  NO BET
# 2    06/09/2023 13:10         BATH       First Company         0.00  NO BET
# 281  06/09/2023 20:30      KEMPTON       Flying Secret         0.00  NO BET
# 282  06/09/2023 20:30      KEMPTON            Aphelios         0.00  NO BET
# 283  06/09/2023 20:30      KEMPTON          Soar Above         0.00  NO BET
# 80   06/09/2023 15:30  GOWRAN PARK        On Our Radar         0.00  NO BET
# 285  06/09/2023 20:30      KEMPTON        Mitrosonfire         0.00  NO BET
# 286  06/09/2023 20:30      KEMPTON          Spinaround         0.00  NO BET
# 287  06/09/2023 21:00      KEMPTON      Harriets Angel         0.00  NO BET
# 289  06/09/2023 21:00      KEMPTON   Captain Wentworth         0.00  NO BET
# 279  06/09/2023 20:30      KEMPTON            Maxi Boy         0.00  NO BET
# 290  06/09/2023 21:00      KEMPTON      Believe You Me         0.00  NO BET
# 291  06/09/2023 21:00      KEMPTON             Arbaawi         0.00  NO BET
# 79   06/09/2023 15:25         BATH            Al Azhar         0.00  NO BET
# 293  06/09/2023 21:00      KEMPTON             Juryman         0.00  NO BET
# 294  06/09/2023 21:00      KEMPTON         Surrey Noir         0.00  NO BET
# 295  06/09/2023 21:00      KEMPTON         Concert Boy         0.00  NO BET
# 78   06/09/2023 15:25         BATH         My Chiquita         0.00  NO BET
# 280  06/09/2023 20:30      KEMPTON         Zero Carbon         0.00  NO BET
# 278  06/09/2023 20:00      KEMPTON   Miss Dolly Rocker         0.00  NO BET
# 218  06/09/2023 18:10         CORK        Screen Siren         0.00  NO BET
# 6    06/09/2023 13:10         BATH             Gherkin         0.00  NO BET
# 260  06/09/2023 19:40         CORK          Shes Local         0.00  NO BET
# 15   06/09/2023 13:30    SOUTHWELL          Churchella         0.00  NO BET
# 13   06/09/2023 13:30    SOUTHWELL             The Pug         0.00  NO BET
# 11   06/09/2023 13:30    SOUTHWELL      Churchill Rose         0.00  NO BET
# 8    06/09/2023 13:10         BATH     Fair And Square         0.00  NO BET
# 86   06/09/2023 15:30  GOWRAN PARK     Woodcock Flight         0.00  NO BET
# 7    06/09/2023 13:10         BATH     Brian The Snail         0.00  NO BET
# 84   06/09/2023 15:30  GOWRAN PARK       Artemis Jones         0.00  NO BET
# 277  06/09/2023 20:00      KEMPTON       Finest Leader         0.00  NO BET
# 83   06/09/2023 15:30  GOWRAN PARK  Dance Night Andday         0.00  NO BET
# 82   06/09/2023 15:30  GOWRAN PARK        Not Just Yet         0.00  NO BET
# 272  06/09/2023 20:00      KEMPTON        Lion Kingdom         0.00  NO BET
# 81   06/09/2023 15:30  GOWRAN PARK          Livio Milo         0.00  NO BET
# 3    06/09/2023 13:10         BATH          Attys Edge         0.00  NO BET
# 275  06/09/2023 20:00      KEMPTON           Unlimited         0.00  NO BET
# 276  06/09/2023 20:00      KEMPTON               Palio         0.00  NO BET
# 219  06/09/2023 18:10         CORK   Linger For Longer         0.00  NO BET
# 217  06/09/2023 18:10         CORK          Polar Bear         0.00  NO BET
# 61   06/09/2023 14:15         BATH  Foreseeable Future         0.00  NO BET
# 216  06/09/2023 18:10         CORK              Tamazu         0.00  NO BET
# 158  06/09/2023 17:00    SOUTHWELL         Scotch Mist         0.00  NO BET
# 159  06/09/2023 17:00    SOUTHWELL             Sehayli         0.00  NO BET
# 160  06/09/2023 17:00    SOUTHWELL         Our Scholar         0.00  NO BET
# 50   06/09/2023 14:05    SOUTHWELL     Hes A Gentleman         0.00  NO BET
# 162  06/09/2023 17:00    SOUTHWELL       Kittens Dream         0.00  NO BET
# 163  06/09/2023 17:00    SOUTHWELL       Wannabe Brave         0.00  NO BET
# 69   06/09/2023 14:50         BATH               Katar         0.00  NO BET
# 165  06/09/2023 17:00    SOUTHWELL            Zivaniya         0.00  NO BET
# 166  06/09/2023 17:00    SOUTHWELL    Doublethetrouble         0.00  NO BET
# 167  06/09/2023 17:09         BATH      Queen Of Steel         0.00  NO BET
# 125  06/09/2023 16:34         BATH          Miss Sligo         0.00  NO BET
# 169  06/09/2023 17:09         BATH      Highland Flyer         0.00  NO BET
# 124  06/09/2023 16:34         BATH  Send In The Clouds         0.00  NO BET
# 171  06/09/2023 17:09         BATH     Uther Pendragon         0.00  NO BET
# 173  06/09/2023 17:09         BATH              Asense         0.00  NO BET
# 174  06/09/2023 17:09         BATH            Kindgirl         0.00  NO BET
# 175  06/09/2023 17:15  GOWRAN PARK              Rerkha         0.00  NO BET
# 157  06/09/2023 17:00    SOUTHWELL         Social City         0.00  NO BET
# 156  06/09/2023 16:50    LINGFIELD      Belo Horizonte         0.00  NO BET
# 155  06/09/2023 16:50    LINGFIELD         Sprezzatura         0.00  NO BET
# 57   06/09/2023 14:15         BATH         Regal Envoy         0.00  NO BET
# 138  06/09/2023 16:40  GOWRAN PARK      Pinball Wizard         0.00  NO BET
# 60   06/09/2023 14:15         BATH         Shesadabber         0.00  NO BET
# 63   06/09/2023 14:50         BATH            Jax Edge         0.00  NO BET
# 64   06/09/2023 14:50         BATH            Beau Roc         0.00  NO BET
# 65   06/09/2023 14:50         BATH   Moonlight Dreamer         0.00  NO BET
# 143  06/09/2023 16:40  GOWRAN PARK       Partisan Hero         0.00  NO BET
# 67   06/09/2023 14:50         BATH       Confederation         0.00  NO BET
# 146  06/09/2023 16:40  GOWRAN PARK           Danesfort         0.00  NO BET
# 154  06/09/2023 16:50    LINGFIELD             Larrsen         0.00  NO BET
# 130  06/09/2023 16:40  GOWRAN PARK        Skontonovski         0.00  NO BET
# 148  06/09/2023 16:50    LINGFIELD            Al Tarfa         0.00  NO BET
# 1    06/09/2023 13:10         BATH          Giddy Aunt         0.00  NO BET
# 150  06/09/2023 16:50    LINGFIELD     Angel Of Antrim         0.00  NO BET
# 54   06/09/2023 14:15         BATH      Symbol Of Hope         0.00  NO BET
# 127  06/09/2023 16:34         BATH         Billaki Mou         0.00  NO BET
# 52   06/09/2023 14:05    SOUTHWELL              Ciotog         0.00  NO BET
# 122  06/09/2023 16:34         BATH       Trussst In Me         0.00  NO BET
# 45   06/09/2023 14:05    SOUTHWELL           Southwold         0.00  NO BET
# 121  06/09/2023 16:34         BATH          Princess T         0.00  NO BET
# 108  06/09/2023 16:25    SOUTHWELL            Min Till         0.00  NO BET
# 39   06/09/2023 14:05    SOUTHWELL      Soames Forsyte         0.00  NO BET
# 201  06/09/2023 17:25    LINGFIELD             Bhubezi         0.00  NO BET
# 202  06/09/2023 17:30    SOUTHWELL            Ray Vonn         0.00  NO BET
# 203  06/09/2023 17:30    SOUTHWELL              Woobay         0.00  NO BET
# 112  06/09/2023 16:25    SOUTHWELL     Back From Dubai         0.00  NO BET
# 205  06/09/2023 17:30    SOUTHWELL                Tyke         0.00  NO BET
# 206  06/09/2023 17:30    SOUTHWELL           Wadi Bani         0.00  NO BET
# 208  06/09/2023 17:30    SOUTHWELL       Beauty Choice         0.00  NO BET
# 198  06/09/2023 17:25    LINGFIELD   King Of The Dance         0.00  NO BET
# 209  06/09/2023 17:30    SOUTHWELL           El Tesoro         0.00  NO BET
# 71   06/09/2023 14:50         BATH         Moulin Booj         0.00  NO BET
# 211  06/09/2023 17:30    SOUTHWELL        Crypto Quest         0.00  NO BET
# 106  06/09/2023 16:25    SOUTHWELL            Hezahunk         0.00  NO BET
# 213  06/09/2023 17:30    SOUTHWELL           Sun Power         0.00  NO BET
# 105  06/09/2023 16:25    SOUTHWELL        Homer Stokes         0.00  NO BET
# 104  06/09/2023 16:25    SOUTHWELL              Asmund         0.00  NO BET
# 199  06/09/2023 17:25    LINGFIELD              Handel         0.00  NO BET
# 40   06/09/2023 14:05    SOUTHWELL       Clipsham Gold         0.00  NO BET
# 179  06/09/2023 17:15  GOWRAN PARK         Rock Etoile         0.00  NO BET
# 77   06/09/2023 15:25         BATH       Denis Anthony         0.00  NO BET
# 120  06/09/2023 16:34         BATH        Broad Appeal         0.00  NO BET
# 181  06/09/2023 17:15  GOWRAN PARK           Portreath         0.00  NO BET
# 182  06/09/2023 17:15  GOWRAN PARK       Great Blasket         0.00  NO BET
# 44   06/09/2023 14:05    SOUTHWELL            Bushfire         0.00  NO BET
# 118  06/09/2023 16:34         BATH              Footsy         0.00  NO BET
# 115  06/09/2023 16:25    SOUTHWELL           Wizarding         0.00  NO BET
# 42   06/09/2023 14:05    SOUTHWELL          Calins Lad         0.00  NO BET
# 188  06/09/2023 17:15  GOWRAN PARK         Brewel Hill         0.00  NO BET
# 196  06/09/2023 17:25    LINGFIELD        Villeurbanne         0.00  NO BET
# 41   06/09/2023 14:05    SOUTHWELL          Motawaafeq         0.00  NO BET
# 114  06/09/2023 16:25    SOUTHWELL      Thomas Equinas         0.00  NO BET
# 191  06/09/2023 17:15  GOWRAN PARK          Lady Arwen         0.00  NO BET
# 192  06/09/2023 17:25    LINGFIELD       Star Of Epsom         0.00  NO BET
# 193  06/09/2023 17:25    LINGFIELD          Luna Queen         0.00  NO BET
# 194  06/09/2023 17:25    LINGFIELD          Villalobos         0.00  NO BET
# 195  06/09/2023 17:25    LINGFIELD              Alyara         0.00  NO BET
# 0    06/09/2023 13:10         BATH        Phoenix Glow         0.00  NO BET

# %%
pd.set_option('display.max_rows', None)
